# %%
pd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("signalements-coyotes.csv")

# %%
df
# Out:
#       OBJ_ID     Dat_obs    Hr_obs  Nb_coyotes Alimentation Statut_animal  \
# 0          7  2017-07-16  01:15:29         NaN          NaN           NaN
# 1          8  2017-07-18  04:07:24         1.0          NaN           NaN
# 2          9  2017-07-18  04:07:24         1.0          NaN           NaN
# 3         10  2017-07-19  01:16:37         1.0          NaN           NaN
# 4         11  2017-07-22  01:03:24         1.0          NaN           NaN
# ...      ...         ...       ...         ...          ...           ...
# 2091    2391  2023-03-12  21:00:00         1.0          NaN           NaN
# 2092    2392  2023-03-12  21:00:00         1.0          NaN           NaN
# 2093    2392  2023-03-12  21:00:00         1.0          NaN           NaN
# 2094    2391  2023-03-12  21:00:00         1.0          NaN           NaN
# 2095    2392  2023-03-12  21:00:00         1.0          NaN           NaN
#
#      Periode Comp_class  Com_code  Cote  \
# ...

# %%
df.head(10)
# Out:
#    OBJ_ID     Dat_obs    Hr_obs  Nb_coyotes Alimentation Statut_animal  \
# 0       7  2017-07-16  01:15:29         NaN          NaN           NaN
# 1       8  2017-07-18  04:07:24         1.0          NaN           NaN
# 2       9  2017-07-18  04:07:24         1.0          NaN           NaN
# 3      10  2017-07-19  01:16:37         1.0          NaN           NaN
# 4      11  2017-07-22  01:03:24         1.0          NaN           NaN
# 5      12  2017-07-22  23:50:27         1.0          NaN           NaN
# 6      13  2017-07-24  14:36:28         1.0          NaN           NaN
# 7      14  2017-07-26  22:02:58         1.0          NaN           NaN
# 8      15  2017-07-27  01:53:28         1.0          NaN           NaN
# 9      16  2017-07-27  02:17:55         NaN          NaN           NaN
#
#   Periode Comp_class  Com_code  Cote                            Territoire  \
# 0    nuit        NaN       NaN   NaN                 Ahuntsic-Cartierville
# ...

# %%
df.shape
# Out:
# (2096, 19)

# %%
df.columns
# Out:
# Index(['OBJ_ID', 'Dat_obs', 'Hr_obs', 'Nb_coyotes', 'Alimentation',
#        'Statut_animal', 'Periode', 'Comp_class', 'Com_code', 'Cote',
#        'Territoire', 'Statut_mention', 'Provenance', 'Verif', 'X', 'Y', 'Lat',
#        'Long', 'geometry'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2096, step=1)

# %%
df['Nb_coyotes'].head()
# Out:
# 0    NaN
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: Nb_coyotes, dtype: float64

# %%
df_prov = df.set_index("Provenance")

# %%
df_prov.loc['MFFP']
# Out:
#             OBJ_ID     Dat_obs    Hr_obs  Nb_coyotes Alimentation  \
# Provenance
# MFFP            82  2017-08-31  21:12:04         1.0          NaN
# MFFP            86  2017-09-02  05:28:12         1.0      ordures
# MFFP            90  2017-09-11  10:02:58         1.0          NaN
# MFFP           114  2017-06-28  23:45:00         1.0        Autre
# MFFP           115  2017-06-25  22:20:00         1.0          NaN
# ...            ...         ...       ...         ...          ...
# MFFP          1624  2018-04-01  20:30:00         1.0          NaN
# MFFP          1652  2018-02-06  08:30:00         1.0          NaN
# MFFP          1657  2018-10-25  08:30:00         1.0          NaN
# MFFP          1745  2020-02-18  19:27:00         1.0          NaN
# MFFP          1746  2020-02-28  13:23:00         1.0          NaN
#
#            Statut_animal Periode Comp_class  Com_code  Cote  \
# Provenance
# MFFP                 NaN    nuit   inconnue       1.0   0.0
# ...

# %%
df["Provenance"]
# Out:
# 0       SPVM
# 1       SPVM
# 2       SPVM
# 3       SPVM
# 4       SPVM
#         ...
# 2091     NaN
# 2092     NaN
# 2093     NaN
# 2094     NaN
# 2095     NaN
# Name: Provenance, Length: 2096, dtype: object
